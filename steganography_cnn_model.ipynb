# %% [markdown]
# #Dataset

# %% [markdown]
# This model focuses on the difference
#
# 1.   Stegnography Images->Images which contains concealment of information.
# 2.   Clean Images->Images which contains any concealment of information.

# %% [markdown]
# Download dataset from kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-022df66b-5e62-49c5-80bc-853815b84e63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-022df66b-5e62-49c5-80bc-853815b84e63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir("/content/"))
# Out:
# ['.config', 'kaggle.json', 'sample_data']

# %%
import shutil

# Create Kaggle directory
# !mkdir -p ~/.kaggle

# Move the file if it exists
if os.path.exists("/content/kaggle.json"):
    shutil.move("/content/kaggle.json", "/root/.kaggle/kaggle.json")
    print("✅ kaggle.json moved successfully!")
else:
    print("🚨 kaggle.json not found! Please re-upload it.")
# Out:
# ✅ kaggle.json moved successfully!

# %%
import kagglehub

# Download the dataset
path = kagglehub.dataset_download("marcozuppelli/stegoimagesdataset")

print("✅ Dataset downloaded to:", path)
# Out:
# ...
# 100%|██████████| 1.51G/1.51G [00:12<00:00, 131MB/s]
# Extracting files...
# ✅ Dataset downloaded to: /root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2

# %%
import os

dataset_path = "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2"
print("📂 Dataset files:", os.listdir(dataset_path))
# Out:
# 📂 Dataset files: ['test', 'train', 'dataset_information.csv', 'val']

# %% [markdown]
# #Viewing Images and Files
#
# You could observe that there is no difference between any Stegnography Images and Clean Images

# %%
import tensorflow as tf

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataset_path = "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2"

# %%
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
IMG_SIZE = 128

# %%
def preprocess_image(image_path):
    img = cv2.imread(image_path)

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))

    img = img / 255.0
    return img

# %%
# !ls "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/"
# Out:
# clean  stego

# %%
# !ls "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/clean"
# Out:
# 00001.png  00446.png  00891.png  01336.png  01781.png  02226.png  02671.png  03116.png	03561.png
# 00002.png  00447.png  00892.png  01337.png  01782.png  02227.png  02672.png  03117.png	03562.png
# 00003.png  00448.png  00893.png  01338.png  01783.png  02228.png  02673.png  03118.png	03563.png
# 00004.png  00449.png  00894.png  01339.png  01784.png  02229.png  02674.png  03119.png	03564.png
# 00005.png  00450.png  00895.png  01340.png  01785.png  02230.png  02675.png  03120.png	03565.png
# 00006.png  00451.png  00896.png  01341.png  01786.png  02231.png  02676.png  03121.png	03566.png
# 00007.png  00452.png  00897.png  01342.png  01787.png  02232.png  02677.png  03122.png	03567.png
# 00008.png  00453.png  00898.png  01343.png  01788.png  02233.png  02678.png  03123.png	03568.png
# 00009.png  00454.png  00899.png  01344.png  01789.png  02234.png  02679.png  03124.png	03569.png
# 00010.png  00455.png  00900.png  01345.png  01790.png  02235.png  02680.png  03125.png	03570.png
# ...

# %%
dataset_path = "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train"

clean_path = os.path.join(dataset_path, "clean")
stego_path = os.path.join(dataset_path, "stego")  #


print(len(os.listdir(clean_path)))
print(len(os.listdir(stego_path)))
# Out:
# 4000
# 12000

# %%
sample_image_path = os.path.join(clean_path, os.listdir(clean_path)[0])
preprocessed_img = preprocess_image(sample_image_path)

# %%
sample_image_path
# Out:
# '/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/clean/02655.png'

# %%
import random

# %%
os.listdir(clean_path)
# Out:
# ['02655.png',
#  '02306.png',
#  '03493.png',
#  '02417.png',
#  '02487.png',
#  '00408.png',
#  '02577.png',
#  '00990.png',
#  '02014.png',
#  '02429.png',
#  '00849.png',
#  '01100.png',
#  '00428.png',
#  '02445.png',
#  '01786.png',
#  '03288.png',
#  '03608.png',
#  '01653.png',
#  '00773.png',
#  '02148.png',
#  '02780.png',
#  '02803.png',
#  '00167.png',
#  '00452.png',
#  '00282.png',
#  '00071.png',
#  '03097.png',
#  '01018.png',
#  '00332.png',
#  '02095.png',
#  '02222.png',
#  '01675.png',
#  '00940.png',
#  '00195.png',
#  '02658.png',
#  '01952.png',
#  '03508.png',
#  '00431.png',
#  '02969.png',
#  '03420.png',
#  '03917.png',
#  '01420.png',
#  '03676.png',
#  '02722.png',
#  '00020.png',
#  '00744.png',
#  '03688.png',
#  '00202.png',
#  '02605.png',
#  '02684.png',
#  '01817.png',
#  '03086.png',
#  '02858.png',
#  '01743.png',
#  '02627.png',
#  '01035.png',
#  '00642.png',
#  '03183.png',
#  '02824.png',
#  '01162.png',
#  '01913.png',
#  '01173.png',
# ...

# %%
random.randint(0,len(os.listdir(clean_path)))
# Out:
# 1048

# %%
os.path.join(clean_path,os.listdir(clean_path)[random.randint(0,len(os.listdir(clean_path)))])
# Out:
# '/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/clean/00270.png'

# %%
os.listdir(clean_path)
# Out:
# ['02655.png',
#  '02306.png',
#  '03493.png',
#  '02417.png',
#  '02487.png',
#  '00408.png',
#  '02577.png',
#  '00990.png',
#  '02014.png',
#  '02429.png',
#  '00849.png',
#  '01100.png',
#  '00428.png',
#  '02445.png',
#  '01786.png',
#  '03288.png',
#  '03608.png',
#  '01653.png',
#  '00773.png',
#  '02148.png',
#  '02780.png',
#  '02803.png',
#  '00167.png',
#  '00452.png',
#  '00282.png',
#  '00071.png',
#  '03097.png',
#  '01018.png',
#  '00332.png',
#  '02095.png',
#  '02222.png',
#  '01675.png',
#  '00940.png',
#  '00195.png',
#  '02658.png',
#  '01952.png',
#  '03508.png',
#  '00431.png',
#  '02969.png',
#  '03420.png',
#  '03917.png',
#  '01420.png',
#  '03676.png',
#  '02722.png',
#  '00020.png',
#  '00744.png',
#  '03688.png',
#  '00202.png',
#  '02605.png',
#  '02684.png',
#  '01817.png',
#  '03086.png',
#  '02858.png',
#  '01743.png',
#  '02627.png',
#  '01035.png',
#  '00642.png',
#  '03183.png',
#  '02824.png',
#  '01162.png',
#  '01913.png',
#  '01173.png',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for i in range(1,10):

  plt.subplot(3,3,i)

  clean_sample=os.path.join(clean_path,os.listdir(clean_path)[random.randint(0,len(os.listdir(clean_path)))])

  img = mpimg.imread(clean_sample)
  plt.imshow(img)
  plt.axis("off")

# %%
os.listdir("/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test")
# Out:
# ['clean', 'stego_zip', 'stego', 'stego_b64']

# %%
os.listdir("/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/")
# Out:
# ['clean', 'stego']

# %%
train_dir="/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/train/train/"

# %%
import shutil
import os


parent_folder = "/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test"
folders_to_remove = ["stego_zip", "stego_b64"]


for folder in folders_to_remove:
    folder_path = os.path.join(parent_folder, folder)
    if os.path.exists(folder_path):
        shutil.rmtree(folder_path)
        print(f"✅ Deleted: {folder_path}")
    else:
        print(f"🚨 Folder not found: {folder_path}")
# Out:
# ✅ Deleted: /root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test/stego_zip
# ✅ Deleted: /root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test/stego_b64

# %%
os.listdir("/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test")
# Out:
# ['clean', 'stego']

# %%
os.listdir("/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/val/val")
# Out:
# ['clean', 'stego']

# %%
valid_dir="/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/val/val"

# %%
test_dir="/root/.cache/kagglehub/datasets/marcozuppelli/stegoimagesdataset/versions/2/test/test/"

# %% [markdown]
# #Image extraction
#
# Extraction of images from folders

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)


train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='binary')


valid_data = train_datagen.flow_from_directory(valid_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='binary')

test_data = train_datagen.flow_from_directory(test_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='binary')
# Out:
# Found 16000 images belonging to 2 classes.
# Found 8000 images belonging to 2 classes.
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# #Training using Convolutional Neural Networks
#
# After several attempts model has got a training and validation accuracy score of 75

# %%
import tensorflow as tf

model_1=tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(224,224, 3)),
    tf.keras.layers.Conv2D(32,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Conv2D(32,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation="relu"),
    tf.keras.layers.Dense(1,activation="sigmoid")

])

model_1.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

model_1.fit(train_data,
            epochs=10,
            steps_per_epoch=len(train_data),
            validation_data=valid_data,
            validation_steps=len(valid_data))
# Out:
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 127s 233ms/step - accuracy: 0.7356 - loss: 0.6544 - val_accuracy: 0.7500 - val_loss: 0.5621
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 133s 231ms/step - accuracy: 0.7473 - loss: 0.5676 - val_accuracy: 0.7500 - val_loss: 0.5619
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 140s 228ms/step - accuracy: 0.7482 - loss: 0.5645 - val_accuracy: 0.7500 - val_loss: 0.4728
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 116s 232ms/step - accuracy: 0.7541 - loss: 0.4355 - val_accuracy: 0.7500 - val_loss: 0.4139
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 140s 228ms/step - accuracy: 0.7436 - loss: 0.4263 - val_accuracy: 0.7500 - val_loss: 0.4146
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 143s 230ms/step - accuracy: 0.7480 - loss: 0.4246 - val_accuracy: 0.7500 - val_loss: 0.4134
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 141s 229ms/step - accuracy: 0.7499 - loss: 0.4195 - val_accuracy: 0.7500 - val_loss: 0.4139
# Epoch 8/10
# ...

# %%
def load_and_prep_image(filename, img_shape=224):


  img = tf.io.read_file(filename)



  img = tf.image.decode_image(img, channels=3)


  img = tf.image.resize(img, size = [img_shape, img_shape])


  img = img/255.
  return img

# %%
model_1.save_weights("stego_model.weights.h5")

# %%
model_1.save("steganography_cnn_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
predictions = model_1.predict(test_data)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 161ms/step

# %%
predictions
# Out:
# array([[0.58922434],
#        [0.58922434],
#        [0.99999464],
#        ...,
#        [0.58922434],
#        [0.58922434],
#        [0.58922434]], dtype=float32)
